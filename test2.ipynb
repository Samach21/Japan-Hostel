# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Hostel.csv')
data.dropna(subset = ["rating.band"], inplace=True)

# %%
data
# Out:
#      Unnamed: 0                   hostel.name          City  price.from  \
# 0             1  "Bike & Bed" CharinCo Hostel         Osaka        3300
# 1             2                  & And Hostel  Fukuoka-City        2600
# 2             3         &And Hostel Akihabara         Tokyo        3600
# 3             4              &And Hostel Ueno         Tokyo        2600
# 4             5    &And Hostel-Asakusa North-         Tokyo        1500
# ..          ...                           ...           ...         ...
# 337         338       YADOYA Guesthouse Green         Tokyo        2300
# 338         339      YADOYA Guesthouse Orange         Tokyo        2000
# 339         340             YAWP! backpackers         Tokyo        2500
# 340         341               You En Me House         Kyoto        2800
# 341         342               Zabutton Hostel         Tokyo        2900
#
#                     Distance  summary.score rating.band  atmosphere  \
# ...

# %%
train = data.sample(frac=0.80)
train
# Out:
#      Unnamed: 0                   hostel.name          City  price.from  \
# 27           28  Backpackers Hotel Toyo Osaka         Osaka        1500
# 208         209  Khaosan World Ryogoku Hostel         Tokyo        2300
# 158         159           Hostel Teltel Bouzu         Osaka        2500
# 119         120                 HATAGO tenjin  Fukuoka-City        2300
# 190         191     J-Hoppers Osaka Universal         Osaka        2500
# ..          ...                           ...           ...         ...
# 115         116                Guesthouse Soi         Kyoto        1700
# 318         319             Tokyo Hostel Fuji         Tokyo        2000
# 283         284          Sakura Hotel Nippori         Tokyo        1900
# 252         253         Osaka GuestHouse KOMA         Osaka        1500
# 248         249      Osaka Fuku Hostel Nagomi         Osaka        3000
#
#                    Distance  summary.score rating.band  atmosphere  \
# ...

# %%
# for i in train:
#     # data[data['Unnamed: 0'] != i['Unnamed: 0']]
#     print(i)
#     break
# # data['Unnamed: 0']
# data[data['Unnamed: 0'] != train['Unnamed: 0']]
for i in train['Unnamed: 0'].to_list():
    data = data[data['Unnamed: 0'] != i]
test = data
test
# Out:
#      Unnamed: 0                   hostel.name          City  price.from  \
# 0             1  "Bike & Bed" CharinCo Hostel         Osaka        3300
# 1             2                  & And Hostel  Fukuoka-City        2600
# 3             4              &And Hostel Ueno         Tokyo        2600
# 4             5    &And Hostel-Asakusa North-         Tokyo        1500
# 6             7           328 Hostel & Lounge         Tokyo        3300
# ..          ...                           ...           ...         ...
# 324         325          Tonagi Hostel × Cafe  Fukuoka-City        2500
# 328         329                      Uno Ueno         Tokyo        1500
# 329         330             Unplan Kagurazaka         Tokyo        3200
# 334         335        Wise Owl Hostels Tokyo         Tokyo        2000
# 341         342               Zabutton Hostel         Tokyo        2900
#
#                     Distance  summary.score rating.band  atmosphere  \
# ...
